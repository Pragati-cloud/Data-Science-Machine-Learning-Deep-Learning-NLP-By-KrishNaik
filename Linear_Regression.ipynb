# %% [markdown]
# <a href="https://colab.research.google.com/github/Pragati-cloud/Data-Science-Machine-Learning-Deep-Learning-NLP-By-KrishNaik/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Height'].plot(kind='hist', bins=20, title='Height')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Weight', y='Height', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
X= df[['Weight']] #independent feature with 2 dimensions do not use df['Weight']
print(X)
y= df['Height'] #dependent feature
print(y)
#
# Out:
#     Weight
# 0       45
# 1       58
# 2       48
# 3       60
# 4       70
# 5       78
# 6       80
# 7       90
# 8       95
# 9       78
# 10      82
# 11      95
# 12     105
# 13     100
# 14      85
# 15      78
# 16      50
# 17      65
# 18      76
# 19      87
# 20      45
# 21      56
# 22      72
# 0     120
# 1     135
# 2     123
# 3     145
# 4     160
# 5     162
# 6     163
# 7     175
# 8     182
# 9     170
# 10    176
# 11    182
# 12    175
# 13    183
# 14    170
# 15    177
# 16    140
# 17    159
# 18    150
# 19    167
# 20    129
# 21    140
# 22    160
# Name: Height, dtype: int64

# %%
np.array(X).shape
# Out:
# (23, 1)

# %%
# train test split

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train.shape
# Out:
# (17, 1)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train= scaler.fit_transform(X_train)

# %%
X_test= scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression(n_jobs=-1)
regression.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
regression.coef_
# Out:
# array([16.72989292])

# %%
regression.intercept_
# Out:
# np.float64(159.0)

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train, regression.predict(X_train))

# %%
#prediction for test data
#predict height = intercept + weight*coef
y_pred= regression.predict(X_test)

# %%
#performance metrics
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
mse= mean_squared_error(y_test, y_pred)
mae= mean_absolute_error(y_test,y_pred)
r2= r2_score(y_test, y_pred)
print(mse)
print(mae)
print(r2)
# Out:
# 2.4828031600356484
# 1.171344335738046
# 0.9940205436338451

# %%
#predict for new data
regression.predict(scaler.transform([[73]]))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([157.35359225])
